# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from datetime import timedelta

# %%
loyalty_benefits=pd.read_excel('2022 Case challenge_ DA update.xlsx',sheet_name='Data. Loyalty benefits')
loyalty_benefits
# Out:
#     Class ID             Group  %cashback
# 0          2               cvs          5
# 1          2  Offline Beverage          5
# 2          2              data          5
# 3          3               cvs          7
# 4          3  Offline Beverage          7
# 5          3              data          7
# 6          3       marketplace          2
# 7          3       supermarket          2
# 8          4               cvs         12
# 9          4  Offline Beverage         12
# 10         4              data         12
# 11         4       marketplace          5
# 12         4       supermarket          5

# %%
loyalty_points=pd.read_excel('2022 Case challenge_ DA update.xlsx',sheet_name='Data. Loyalty Points')
loyalty_points
# Out:
#                 Service Group        Point Mechanism Maximum Point Per Trans
# 0                 supermarket   1 points/1000VND GMV              500 points
# 1                        data  10 points/1000VND GMV             1000 points
# 2                         cvs   1 points/1000VND GMV              300 points
# 3                 marketplace   1 points/1000VND GMV              500 points
# 4  Coffee chains and Milk tea   1 points/1000VND GMV              500 points
# 5            Offline Beverage   1 points/1000VND GMV              300 points

# %%
merchants=pd.read_excel('2022 Case challenge_ DA update.xlsx',sheet_name='Data.Merchant')
merchants
# Out:
#                        ServiceID               Service Group       Merchant  \
# 0                        7eleven                         cvs        7eleven
# 1               MOMOIOQC20191008                         cvs        7eleven
# 2                        opcaeon                 supermarket      Aeon Mall
# 3               MOMOGPCQ20190613                 supermarket      Aeon Mall
# 4               MOMOONXG20191120                 supermarket      Aeon Mall
# ..                           ...                         ...            ...
# 213       buycard_data_vinaphone                        data      Vinaphone
# 214  gift_buycard_data_vinaphone                        data      Vinaphone
# 215              topup_data_vina                        data      Vinaphone
# 216                 waynescoffee  Coffee chains and Milk tea  Waynes Coffee
# 217             MOMOFTUR20190422  Coffee chains and Milk tea  Waynes Coffee
#
#      MerchantID
# 0             1
# 1             1
# 2             2
# 3             2
# 4             2
# ..          ...
# 213          43
# 214          43
# 215          43
# 216          44
# 217          44
#
# [218 rows x 4 columns]

# %%
merchants['Merchant'].nunique()
# Out:
# 45

# %%
merchants['MerchantID'].nunique()
# Out:
# 44

# %%
merchants['Merchant'].unique()
# Out:
# array(['7eleven', 'Aeon Mall', 'Big C', 'Bobapop', 'BSMART',
#        'Cà Phê Ông Bầu', 'CHEESE COFFEE', 'Circle K', 'Co.opmart',
#        'Coffee House', 'Cộng Cà phê', 'Công ty TNHH Cà Phê Gemini',
#        'Đá Đen Coffe', 'E coffee', 'FAMILYMART', 'FINELIFE', 'GongCha',
#        'GS25', 'GUTA CAFE', 'Highlands', 'Katinat', 'Koi The', 'Koi Thé',
#        'LAZADA', 'Lotte Mart', 'MEGA-PHINDELI CAFE', 'Milano Coffee',
#        'Ministop', 'MM Mega Market', 'Mobifone', 'Passio', 'PHUC LONG',
#        'SHARTEA', 'THE ALLEY', 'The Coffee House', 'THỨC COFFEE', 'Tiki',
#        'TOCOTOCO', 'Toocha', 'Trung Nguyên', 'VIETTEL', 'Viettel',
#        'VINAMILK-ONLINE', 'Vinaphone', 'Waynes Coffee'], dtype=object)

# %% [markdown]
# Since the number of unique Merchant should be equal to the number of unique Merchant ID. I investigated the unique values of Merchant and noticed that VIETTEL and Viettel are the same company. So, I convert VIETTEL
# into Viettel.

# %%
merchants['Merchant'] = merchants['Merchant'].replace(to_replace='VIETTEL',value='Viettel')

# %%
transactions=pd.read_excel('2022 Case challenge_ DA update.xlsx',sheet_name='Data. Transactions')
transactions
# Out:
#             DATE     Order_id NEWVERTICAL_Merchant  MerchantID   User_id  \
# 0     2021-01-01   8733622706          Marketplace          37  61386143
# 1     2021-01-01   8726857991          Supermarket           9  48453125
# 2     2021-01-01   8737326894          Supermarket           9  49921027
# 3     2021-01-01   8732579078          supermarket           9  46022523
# 4     2021-01-01   8725567343                  CVS           8  44014594
# ...          ...          ...                  ...         ...       ...
# 52755 2022-03-31  22531432792              Airtime          41  53272777
# 52756 2022-03-31  22516959788              Airtime          41  41605249
# 52757 2022-03-31  22518046622              Airtime          30  29029358
# 52758 2022-03-31  22518047037              Airtime          30  29029358
# 52759 2022-03-31  22528638021              Airtime          43  52354215
#
#           GMV Service Group
# 0      100000   marketplace
# 1        5000   supermarket
# 2      106600   supermarket
# 3      270000   supermarket
# 4       68000           cvs
# ...       ...           ...
# 52755   30000          data
# 52756   10000          data
# 52757   42000          data
# 52758    5000          data
# 52759   15000          data
#
# [52760 rows x 7 columns]

# %%
transactions.dtypes
# Out:
# DATE                    datetime64[ns]
# Order_id                         int64
# NEWVERTICAL_Merchant            object
# MerchantID                       int64
# User_id                          int64
# GMV                              int64
# Service Group                   object
# dtype: object

# %%
transactions['DATE'] = pd.to_datetime(transactions['DATE'])

# %%
transactions['User_id']=transactions['User_id'].astype(str)
transactions['Order_id']=transactions['Order_id'].astype(str)
transactions['MerchantID']=transactions['MerchantID'].astype(str)

# %% [markdown]
# # **PART 1. Data processing**

# %% [markdown]
# **Calculate daily loyalty points**

# %%
loyalty_points = []
transactions = transactions.reset_index()
for index, row in transactions.iterrows():
  if row['Service Group'] in ['supermarket', 'marketplace', 'Coffee chains and Milk tea']:
    if row['GMV']/1000 < 500:
      loyalty_points.append(row['GMV']/1000)
    else: loyalty_points.append(500)
  if row['Service Group'] == 'data':
    if row['GMV']/100 < 1000:
      loyalty_points.append(row['GMV']/100)
    else: loyalty_points.append(1000)
  if row['Service Group'] in ['cvs','Offline Beverage']:
     if row['GMV']/1000 < 300:
      loyalty_points.append(row['GMV']/1000)
     else: loyalty_points.append(300)

# %%
transactions['Loyalty Points'] = loyalty_points
transactions
# Out:
#        index       DATE     Order_id NEWVERTICAL_Merchant MerchantID  \
# 0          0 2021-01-01   8733622706          Marketplace         37
# 1          1 2021-01-01   8726857991          Supermarket          9
# 2          2 2021-01-01   8737326894          Supermarket          9
# 3          3 2021-01-01   8732579078          supermarket          9
# 4          4 2021-01-01   8725567343                  CVS          8
# ...      ...        ...          ...                  ...        ...
# 52755  52755 2022-03-31  22531432792              Airtime         41
# 52756  52756 2022-03-31  22516959788              Airtime         41
# 52757  52757 2022-03-31  22518046622              Airtime         30
# 52758  52758 2022-03-31  22518047037              Airtime         30
# 52759  52759 2022-03-31  22528638021              Airtime         43
#
#         User_id     GMV Service Group  Loyalty Points
# 0      61386143  100000   marketplace           100.0
# 1      48453125    5000   supermarket             5.0
# 2      49921027  106600   supermarket           106.6
# 3      46022523  270000   supermarket           270.0
# 4      44014594   68000           cvs            68.0
# ...         ...     ...           ...             ...
# 52755  53272777   30000          data           300.0
# 52756  41605249   10000          data           100.0
# 52757  29029358   42000          data           420.0
# 52758  29029358    5000          data            50.0
# 52759  52354215   15000          data           150.0
#
# [52760 rows x 9 columns]

# %% [markdown]
# **How** **many user archived rank Gold at the end on March?**

# %% [markdown]
# Because after 30 days, loyalty points from transaction will be reset. So, the accumulated loyalty points at the end of March will start from March 2nd.

# %%
end_of_March_ranking = transactions[(transactions['DATE']>= '2022-03-02') & (transactions['DATE']< '2022-04-01')]
end_of_March_ranking
# Out:
#        index       DATE     Order_id NEWVERTICAL_Merchant MerchantID  \
# 42637  42637 2022-03-02  21549087636          Supermarket         25
# 42638  42638 2022-03-02  21558157954          Supermarket         25
# 42639  42639 2022-03-02  21545970988          Supermarket         25
# 42640  42640 2022-03-02  21557916934          Supermarket         25
# 42641  42641 2022-03-02  21562502367                  CVS         28
# ...      ...        ...          ...                  ...        ...
# 52755  52755 2022-03-31  22531432792              Airtime         41
# 52756  52756 2022-03-31  22516959788              Airtime         41
# 52757  52757 2022-03-31  22518046622              Airtime         30
# 52758  52758 2022-03-31  22518047037              Airtime         30
# 52759  52759 2022-03-31  22528638021              Airtime         43
#
#         User_id     GMV Service Group  Loyalty Points
# 42637  45715492   55000   supermarket            55.0
# 42638  44080459  203600   supermarket           203.6
# 42639  37381541  526400   supermarket           500.0
# 42640  44080459   25000   supermarket            25.0
# 42641  47025182   36000           cvs            36.0
# ...         ...     ...           ...             ...
# 52755  53272777   30000          data           300.0
# 52756  41605249   10000          data           100.0
# 52757  29029358   42000          data           420.0
# 52758  29029358    5000          data            50.0
# 52759  52354215   15000          data           150.0
#
# [10123 rows x 9 columns]

# %%
end_of_March_total_point = end_of_March_ranking.groupby('User_id')['Loyalty Points'].sum().reset_index()
end_of_March_total_point
# Out:
#        User_id  Loyalty Points
# 0     10056218         780.000
# 1     10156282         100.000
# 2     10184635        4011.368
# 3      1018832        2130.000
# 4     10247812         150.000
# ...        ...             ...
# 1916    964714        1490.000
# 1917   9658247          44.000
# 1918   9691514           8.000
# 1919    981084           2.000
# 1920    988787         394.999
#
# [1921 rows x 2 columns]

# %%
end_of_March_total_point['Ranking'] = end_of_March_total_point.apply(lambda row: 'STANDARD' if row['Loyalty Points'] < 1000
                                                                     else 'SILVER' if row['Loyalty Points'] < 2000
                                                                     else 'GOLD' if row['Loyalty Points'] < 5000
                                                                     else 'DIAMOND', axis=1)
end_of_March_total_point['Ranking'].value_counts()
# Out:
# STANDARD    1490
# SILVER       294
# GOLD         123
# DIAMOND       14
# Name: Ranking, dtype: int64

# %% [markdown]
# CONCLUSION: There are 123 Gold Ranking users at the end of March 2022

# %% [markdown]
# **Calculate total cashback for February**

# %%
def calculate_loyalty_point(user, date):
  user_transactions = transactions[transactions['User_id'] == user]
  upper_filter = user_transactions['DATE'] <= date
  lower_filter = user_transactions['DATE'] >= (date - timedelta(days=30))
  within_30d_transactions = user_transactions[upper_filter & lower_filter]
  accumulated_loyalty_points = within_30d_transactions['Loyalty Points'].sum() 
  return accumulated_loyalty_points

# %%
transactions['30 days accumulated loyalty points'] = transactions.apply(lambda row: calculate_loyalty_point(row['User_id'],row['DATE']), axis=1)

# %%
transactions['Class ID'] = transactions.apply(lambda row: 1 if row['30 days accumulated loyalty points'] < 1000
                                                                     else 2 if row['30 days accumulated loyalty points'] < 2000
                                                                     else 3 if row['30 days accumulated loyalty points'] < 5000
                                                                     else 4, axis=1)

# %%
cashback = transactions.merge(loyalty_benefits, left_on = ['Service Group', 'Class ID'], right_on = ['Group', 'Class ID'], how = 'left', suffixes=(True,False))
cashback
# Out:
#        index       DATE     Order_id NEWVERTICAL_Merchant MerchantID  \
# 0          0 2021-01-01   8733622706          Marketplace         37
# 1          1 2021-01-01   8726857991          Supermarket          9
# 2          2 2021-01-01   8737326894          Supermarket          9
# 3          3 2021-01-01   8732579078          supermarket          9
# 4          4 2021-01-01   8725567343                  CVS          8
# ...      ...        ...          ...                  ...        ...
# 52755  52755 2022-03-31  22531432792              Airtime         41
# 52756  52756 2022-03-31  22516959788              Airtime         41
# 52757  52757 2022-03-31  22518046622              Airtime         30
# 52758  52758 2022-03-31  22518047037              Airtime         30
# 52759  52759 2022-03-31  22528638021              Airtime         43
#
#         User_id     GMV Service Group  Loyalty Points  \
# 0      61386143  100000   marketplace           100.0
# 1      48453125    5000   supermarket             5.0
# 2      49921027  106600   supermarket           106.6
# 3      46022523  270000   supermarket           270.0
# 4      44014594   68000           cvs            68.0
# ...         ...     ...           ...             ...
# 52755  53272777   30000          data           300.0
# 52756  41605249   10000          data           100.0
# 52757  29029358   42000          data           420.0
# 52758  29029358    5000          data            50.0
# 52759  52354215   15000          data           150.0
#
#        30 days accumulated loyalty points  Class ID Group  %cashback
# 0                                   100.0         1   NaN        NaN
# 1                                     5.0         1   NaN        NaN
# 2                                   106.6         1   NaN        NaN
# 3                                   270.0         1   NaN        NaN
# 4                                    80.0         1   NaN        NaN
# ...                                   ...       ...   ...        ...
# 52755                               760.0         1   NaN        NaN
# 52756                              1916.0         2  data        5.0
# 52757                               600.0         1   NaN        NaN
# 52758                               600.0         1   NaN        NaN
# 52759                               230.0         1   NaN        NaN
#
# [52760 rows x 13 columns]

# %% [markdown]
# Since some transactions are not rewarded with cashback, I replace NaN values with 0.

# %%
cashback.drop('Group', axis=1 ,inplace=True)
cashback['%cashback'] = cashback['%cashback'].fillna(0)
cashback['Cashback'] = cashback.apply(lambda row: row['GMV']*row['%cashback']/100 if row['GMV']*row['%cashback']/100 < 10000
                                      else 10000, axis = 1)
cashback
# Out:
#        index       DATE     Order_id NEWVERTICAL_Merchant MerchantID  \
# 0          0 2021-01-01   8733622706          Marketplace         37
# 1          1 2021-01-01   8726857991          Supermarket          9
# 2          2 2021-01-01   8737326894          Supermarket          9
# 3          3 2021-01-01   8732579078          supermarket          9
# 4          4 2021-01-01   8725567343                  CVS          8
# ...      ...        ...          ...                  ...        ...
# 52755  52755 2022-03-31  22531432792              Airtime         41
# 52756  52756 2022-03-31  22516959788              Airtime         41
# 52757  52757 2022-03-31  22518046622              Airtime         30
# 52758  52758 2022-03-31  22518047037              Airtime         30
# 52759  52759 2022-03-31  22528638021              Airtime         43
#
#         User_id     GMV Service Group  Loyalty Points  \
# 0      61386143  100000   marketplace           100.0
# 1      48453125    5000   supermarket             5.0
# 2      49921027  106600   supermarket           106.6
# 3      46022523  270000   supermarket           270.0
# 4      44014594   68000           cvs            68.0
# ...         ...     ...           ...             ...
# 52755  53272777   30000          data           300.0
# 52756  41605249   10000          data           100.0
# 52757  29029358   42000          data           420.0
# 52758  29029358    5000          data            50.0
# 52759  52354215   15000          data           150.0
#
#        30 days accumulated loyalty points  Class ID  %cashback  Cashback
# 0                                   100.0         1        0.0       0.0
# 1                                     5.0         1        0.0       0.0
# 2                                   106.6         1        0.0       0.0
# 3                                   270.0         1        0.0       0.0
# 4                                    80.0         1        0.0       0.0
# ...                                   ...       ...        ...       ...
# 52755                               760.0         1        0.0       0.0
# 52756                              1916.0         2        5.0     500.0
# 52757                               600.0         1        0.0       0.0
# 52758                               600.0         1        0.0       0.0
# 52759                               230.0         1        0.0       0.0
#
# [52760 rows x 13 columns]

# %%
feb_cashback = cashback[(cashback['DATE'] >= '2022-02-01') & (cashback['DATE'] < '2022-03-01')]
feb_cashback['Cashback'].sum()
# Out:
# 4668841.74

# %% [markdown]
# CONCLUSION: The total cashback for February is 4,668,841.74 VND.

# %% [markdown]
# **Plot weekly retention rate chart**

# %%
def weekly_retention(user, date):
  user_transactions = transactions[transactions['User_id'] == user]
  upper_filter = user_transactions['DATE'] < date
  lower_filter = user_transactions['DATE'] >= (date - timedelta(days=8))
  within_7d_transactions = user_transactions[upper_filter & lower_filter]
  if len(within_7d_transactions) < 1:
    return 0
  else: 
    return 1

# %%
transactions['7 days retention'] = transactions.apply(lambda row: weekly_retention(row['User_id'], row['DATE']), axis=1)
transactions
# Out:
#        index       DATE     Order_id NEWVERTICAL_Merchant MerchantID  \
# 0          0 2021-01-01   8733622706          Marketplace         37
# 1          1 2021-01-01   8726857991          Supermarket          9
# 2          2 2021-01-01   8737326894          Supermarket          9
# 3          3 2021-01-01   8732579078          supermarket          9
# 4          4 2021-01-01   8725567343                  CVS          8
# ...      ...        ...          ...                  ...        ...
# 52755  52755 2022-03-31  22531432792              Airtime         41
# 52756  52756 2022-03-31  22516959788              Airtime         41
# 52757  52757 2022-03-31  22518046622              Airtime         30
# 52758  52758 2022-03-31  22518047037              Airtime         30
# 52759  52759 2022-03-31  22528638021              Airtime         43
#
#         User_id     GMV Service Group  Loyalty Points  \
# 0      61386143  100000   marketplace           100.0
# 1      48453125    5000   supermarket             5.0
# 2      49921027  106600   supermarket           106.6
# 3      46022523  270000   supermarket           270.0
# 4      44014594   68000           cvs            68.0
# ...         ...     ...           ...             ...
# 52755  53272777   30000          data           300.0
# 52756  41605249   10000          data           100.0
# 52757  29029358   42000          data           420.0
# 52758  29029358    5000          data            50.0
# 52759  52354215   15000          data           150.0
#
#        30 days accumulated loyalty points  Class ID  7 days retention
# 0                                   100.0         1                 0
# 1                                     5.0         1                 0
# 2                                   106.6         1                 0
# 3                                   270.0         1                 0
# 4                                    80.0         1                 0
# ...                                   ...       ...               ...
# 52755                               760.0         1                 0
# 52756                              1916.0         2                 1
# 52757                               600.0         1                 1
# 52758                               600.0         1                 1
# 52759                               230.0         1                 0
#
# [52760 rows x 12 columns]

# %%
retention = transactions.groupby('DATE')['7 days retention'].sum().reset_index()
retention
# Out:
#           DATE  7 days retention
# 0   2021-01-01                 0
# 1   2021-01-02                 1
# 2   2021-01-03                 4
# 3   2021-01-04                 5
# 4   2021-01-05                 4
# ..         ...               ...
# 449 2022-03-27               271
# 450 2022-03-28               217
# 451 2022-03-29               317
# 452 2022-03-30               197
# 453 2022-03-31               226
#
# [454 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.lineplot(data=retention, x='DATE', y='7 days retention', ax=ax)
plt.title('Weekly retention timeline')
plt.show()

# %% [markdown]
# # **Part 2. Analyze and comment**

# %% [markdown]
# **Plot daily transaction timeline**

# %%
daily_transactions = transactions.groupby('DATE')['Order_id'].count().reset_index()
daily_transactions
# Out:
#           DATE  Order_id
# 0   2021-01-01        17
# 1   2021-01-02        20
# 2   2021-01-03        13
# 3   2021-01-04        16
# 4   2021-01-05        15
# ..         ...       ...
# 449 2022-03-27       498
# 450 2022-03-28       422
# 451 2022-03-29       493
# 452 2022-03-30       392
# 453 2022-03-31       338
#
# [454 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=daily_transactions,x='DATE',y='Order_id')
plt.title('Transations timeline')
plt.show()

# %%
transactions['Day of Week'] = transactions['DATE'].dt.day_name()
DOW_order = transactions.groupby('Day of Week')['Order_id'].count().reset_index()
DOW_order
# Out:
#   Day of Week  Order_id
# 0      Friday      7101
# 1      Monday      7181
# 2    Saturday      7323
# 3      Sunday      7729
# 4    Thursday      8728
# 5     Tuesday      7353
# 6   Wednesday      7345

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data=DOW_order ,x='Day of Week',y='Order_id')
plt.title('Order by DOW')
plt.show()

# %%
DOW_retention = transactions.groupby('Day of Week')['7 days retention'].sum().reset_index()
DOW_retention
# Out:
#   Day of Week  7 days retention
# 0      Friday              4173
# 1      Monday              4012
# 2    Saturday              3952
# 3      Sunday              4134
# 4    Thursday              4926
# 5     Tuesday              4190
# 6   Wednesday              4109

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data=DOW_retention ,x='Day of Week',y='7 days retention')
plt.title('Weekly retention by DOW')
plt.show()

# %% [markdown]
# - Since Loyalty program launched, weekly retention rate and daily transactions have been increasing. Notably, from November 2021 to January 2022, the company recorded all-time high in these two metrics. From January 2022 to the end of March 2022, the two KPIs are uptrending.
# - Tp increase user's performance monthly, Marketing department can:
#     *   Create content that speaks to the customers and make it easy to understand. Update the old ones and track the traffic rate.
#     *   Improve UX and UI of the website and mobile app.
#     *   Focus marketing more on Thursday as this day have the highest transactions and weekly retention.
#     *   Provide discount code, voucher for lost customer to bring them back with the company service.

# %% [markdown]
# **Proposal on changing the schemes of Loyalty benefits and Loyalty point to alleviate the cost amount**

# %%
cashback
# Out:
#        index       DATE     Order_id NEWVERTICAL_Merchant MerchantID  \
# 0          0 2021-01-01   8733622706          Marketplace         37
# 1          1 2021-01-01   8726857991          Supermarket          9
# 2          2 2021-01-01   8737326894          Supermarket          9
# 3          3 2021-01-01   8732579078          supermarket          9
# 4          4 2021-01-01   8725567343                  CVS          8
# ...      ...        ...          ...                  ...        ...
# 52755  52755 2022-03-31  22531432792              Airtime         41
# 52756  52756 2022-03-31  22516959788              Airtime         41
# 52757  52757 2022-03-31  22518046622              Airtime         30
# 52758  52758 2022-03-31  22518047037              Airtime         30
# 52759  52759 2022-03-31  22528638021              Airtime         43
#
#         User_id     GMV Service Group  Loyalty Points  \
# 0      61386143  100000   marketplace           100.0
# 1      48453125    5000   supermarket             5.0
# 2      49921027  106600   supermarket           106.6
# 3      46022523  270000   supermarket           270.0
# 4      44014594   68000           cvs            68.0
# ...         ...     ...           ...             ...
# 52755  53272777   30000          data           300.0
# 52756  41605249   10000          data           100.0
# 52757  29029358   42000          data           420.0
# 52758  29029358    5000          data            50.0
# 52759  52354215   15000          data           150.0
#
#        30 days accumulated loyalty points  Class ID  %cashback  Cashback
# 0                                   100.0         1        0.0       0.0
# 1                                     5.0         1        0.0       0.0
# 2                                   106.6         1        0.0       0.0
# 3                                   270.0         1        0.0       0.0
# 4                                    80.0         1        0.0       0.0
# ...                                   ...       ...        ...       ...
# 52755                               760.0         1        0.0       0.0
# 52756                              1916.0         2        5.0     500.0
# 52757                               600.0         1        0.0       0.0
# 52758                               600.0         1        0.0       0.0
# 52759                               230.0         1        0.0       0.0
#
# [52760 rows x 13 columns]

# %% [markdown]
# How many users are rewarded with Cashback?

# %%
cashback[cashback['%cashback']>0]['%cashback'].count()
# Out:
# 13790

# %%
cashback['%cashback'].value_counts()
# Out:
# 0.0     38970
# 5.0      6846
# 2.0      3142
# 7.0      3032
# 12.0      770
# Name: %cashback, dtype: int64

# %%
cashback['Cashback'].describe()
# Out:
# count    52760.000000
# mean      1106.749542
# std       2643.447061
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        350.000000
# max      10000.000000
# Name: Cashback, dtype: float64

# %%
cashback.groupby('Service Group').agg({'GMV':'sum','Cashback':'sum'}).reset_index().sort_values(by=['GMV'], ascending=False)
# Out:
#                 Service Group         GMV     Cashback
# 4                 marketplace  3925019072  23505543.92
# 2                         cvs  1882831446  17810535.49
# 5                 supermarket  1243618881   6979831.40
# 3                        data   353137800  10056645.00
# 0  Coffee chains and Milk tea   154917495         0.00
# 1            Offline Beverage     1883000     39550.00

# %% [markdown]
# Data's GMV is only one-third of supermarket's GMV, but its Cashback is 1.5 times more than supermarket's.

# %%
cashback.groupby('Class ID').agg({'GMV':'sum','Cashback':'sum'}).reset_index().sort_values(by=['GMV'], ascending=False)
# Out:
#    Class ID         GMV     Cashback
# 0         1  3234360133         0.00
# 1         2  1802276281  11705686.55
# 2         3  1458110689  25219315.14
# 3         4  1066660591  21467104.12

# %% [markdown]
# Class ID 3 is third in GMV but lead in Cashback with a large gap. So, Class ID 3 is overrewarded with Cashback.

# %%
scheme = cashback.groupby(['Service Group', 'Class ID']).agg({'GMV':'sum','Cashback':'sum','Order_id':'nunique'})
scheme['Cashback/GMV ratio'] = scheme['Cashback'] / scheme['GMV']

# %%
scheme
# Out:
#                                             GMV     Cashback  Order_id  \
# Service Group              Class ID
# Coffee chains and Milk tea 1          100627797         0.00      1496
#                            2           27375541         0.00       300
#                            3           19412384         0.00       235
#                            4            7501773         0.00        81
# Offline Beverage           1            1092000         0.00        19
#                            2             791000     39550.00        14
# cvs                        1          882132952         0.00      6847
#                            2          364966305   6994776.55      1759
#                            3          412314947   6457499.42      1251
#                            4          223417242   4358259.52       478
# data                       1          187249100         0.00     11307
#                            2           93582200   4671360.00      2869
#                            3           60153500   4131245.00      1655
#                            4           12153000   1254040.00       259
# marketplace                1         1525075486         0.00      9717
#                            2          985847890         0.00      2859
#                            3          738627008  11220646.02      2100
#                            4          675468688  12284897.90      1202
# supermarket                1          538182798         0.00      2701
#                            2          329713345         0.00      1004
#                            3          227602850   3409924.70       605
#                            4          148119888   3569906.70       417
#
#                                      Cashback/GMV ratio
# Service Group              Class ID
# Coffee chains and Milk tea 1                   0.000000
#                            2                   0.000000
#                            3                   0.000000
#                            4                   0.000000
# Offline Beverage           1                   0.000000
#                            2                   0.050000
# cvs                        1                   0.000000
#                            2                   0.019166
#                            3                   0.015662
#                            4                   0.019507
# data                       1                   0.000000
#                            2                   0.049917
#                            3                   0.068678
#                            4                   0.103188
# marketplace                1                   0.000000
#                            2                   0.000000
#                            3                   0.015191
#                            4                   0.018187
# supermarket                1                   0.000000
#                            2                   0.000000
#                            3                   0.014982
#                            4                   0.024101

# %% [markdown]
# # **QUESTION 3**

# %% [markdown]
# Which user have 20 consecutive days in DIAMOND in March? Who have the most days?

# %%
first = transactions['DATE'] >= '2022-03-01'
last = transactions['DATE'] < '2022-04-01'
march = transactions[first & last]
march_diamond = march[march['Class ID'] == 4]
march_diamond
# Out:
#        index       DATE     Order_id NEWVERTICAL_Merchant MerchantID  \
# 42474  42474 2022-03-01  21535695588          Marketplace         37
# 42478  42478 2022-03-01  21535406768          Marketplace         37
# 42499  42499 2022-03-01  21511066166              Airtime         43
# 42522  42522 2022-03-01  21536667833          Marketplace         24
# 42529  42529 2022-03-01  21537980470          Marketplace         24
# ...      ...        ...          ...                  ...        ...
# 52637  52637 2022-03-31  22540487177          Marketplace         24
# 52707  52707 2022-03-31  22553554958              Airtime         41
# 52732  52732 2022-03-31  22545659290              Airtime         41
# 52742  52742 2022-03-31  22516198917              Airtime         41
# 52751  52751 2022-03-31  22553843149              Airtime         41
#
#         User_id     GMV Service Group  Loyalty Points  \
# 42474  57207697  490000   marketplace           490.0
# 42478  57207697  490000   marketplace           490.0
# 42499  12229364   20000          data           200.0
# 42522  47662326  180400   marketplace           180.4
# 42529  57207697   20000   marketplace            20.0
# ...         ...     ...           ...             ...
# 52637  44850195  150900   marketplace           150.9
# 52707  49689927   10000          data           100.0
# 52732  49689927   10000          data           100.0
# 52742  49689927   10000          data           100.0
# 52751  49689927   10000          data           100.0
#
#        30 days accumulated loyalty points  Class ID  7 days retention  \
# 42474                            5875.400         4                 1
# 42478                            5875.400         4                 1
# 42499                            7853.900         4                 1
# 42522                           23585.726         4                 1
# 42529                            5875.400         4                 1
# ...                                   ...       ...               ...
# 52637                            5721.902         4                 1
# 52707                            9100.000         4                 1
# 52732                            9100.000         4                 1
# 52742                            9100.000         4                 1
# 52751                            9100.000         4                 1
#
#       Day of Week
# 42474     Tuesday
# 42478     Tuesday
# 42499     Tuesday
# 42522     Tuesday
# 42529     Tuesday
# ...           ...
# 52637    Thursday
# 52707    Thursday
# 52732    Thursday
# 52742    Thursday
# 52751    Thursday
#
# [630 rows x 13 columns]

# %%
march_timeline = pd.date_range(start='2022-03-01', end='2022-03-31')
date_col = []
uid_col = []
for user_id in march_diamond['User_id'].unique():
  for date in march_timeline:
    uid_col.append(user_id)
    date_col.append(date)
march_users = pd.DataFrame(
    {'User_id' : uid_col,
     'DATE' : date_col
     })

# %% [markdown]
# Check if the timeline include 31 days for each user ID.

# %%
march_users['User_id'].value_counts()
# Out:
# 57207697    31
# 12229364    31
# 54788782    31
# 44850195    31
# 31244414    31
# 55443594    31
# 39619396    31
# 44119627    31
# 25993024    31
# 54960619    31
# 43933779    31
# 45426067    31
# 49689927    31
# 43160536    31
# 36884902    31
# 50185392    31
# 44901759    31
# 51432947    31
# 55200938    31
# 39314846    31
# 47662326    31
# 35461466    31
# Name: User_id, dtype: int64

# %%
march_users['Loyalty Points'] = march_users.apply(lambda row: calculate_loyalty_point(row['User_id'],row['DATE']), axis=1)
march_users = march_users.sort_values(by=['User_id', 'DATE'])

# %%
loyalty_points = list(march_users['Loyalty Points'])
day_count = []
a = 0
for entry in loyalty_points:
  if len(day_count) % 31 == 0:
    a = 1
    day_count.append(a)
  else:
    if entry >= 5000:
      a = a + 1
      day_count.append(a)
    else:
      a = 1
      day_count.append(a)

march_users['Consecutive day count'] = day_count

# %%
with pd.option_context('display.max_rows', None,'display.max_columns', None,
    'display.precision', 3,
                       ):
  print(march_users)
# Out:
#       User_id       DATE  Loyalty Points  Consecutive day count
# 31   12229364 2022-03-01        7853.900                      1
# 32   12229364 2022-03-02        7353.900                      2
# 33   12229364 2022-03-03        7353.900                      3
# 34   12229364 2022-03-04        7545.806                      4
# 35   12229364 2022-03-05        7545.806                      5
# 36   12229364 2022-03-06        7545.806                      6
# 37   12229364 2022-03-07        6382.006                      7
# 38   12229364 2022-03-08        6382.006                      8
# 39   12229364 2022-03-09        5943.506                      9
# 40   12229364 2022-03-10        5443.506                     10
# 41   12229364 2022-03-11        5443.506                     11
# 42   12229364 2022-03-12        4291.606                      1
# 43   12229364 2022-03-13        3198.106                      1
# 44   12229364 2022-03-14        3424.806                      1
# 45   12229364 2022-03-15        3424.806                      1
# 46   12229364 2022-03-16        3285.606                      1
# 47   12229364 2022-03-17        3648.846                      1
# 48   12229364 2022-03-18        3648.846                      1
# 49   12229364 2022-03-19        3148.846                      1
# 50   12229364 2022-03-20        3148.846                      1
# 51   12229364 2022-03-21        3148.846                      1
# 52   12229364 2022-03-22        3148.846                      1
# 53   12229364 2022-03-23        2148.846                      1
# 54   12229364 2022-03-24        1425.146                      1
# 55   12229364 2022-03-25        1425.146                      1
# 56   12229364 2022-03-26        1425.146                      1
# 57   12229364 2022-03-27        1425.146                      1
# 58   12229364 2022-03-28        1425.146                      1
# 59   12229364 2022-03-29        1425.146                      1
# 60   12229364 2022-03-30        1425.146                      1
# 61   12229364 2022-03-31        1095.146                      1
# 434  25993024 2022-03-01        2856.696                      1
# 435  25993024 2022-03-02        2016.696                      1
# 436  25993024 2022-03-03        2016.696                      1
# 437  25993024 2022-03-04        2016.696                      1
# 438  25993024 2022-03-05        2016.696                      1
# 439  25993024 2022-03-06        3998.696                      1
# 440  25993024 2022-03-07        4189.736                      1
# 441  25993024 2022-03-08        4189.736                      1
# 442  25993024 2022-03-09        3289.736                      1
# 443  25993024 2022-03-10        3289.736                      1
# 444  25993024 2022-03-11        3097.836                      1
# 445  25993024 2022-03-12        3097.836                      1
# 446  25993024 2022-03-13        2787.836                      1
# 447  25993024 2022-03-14        3787.836                      1
# 448  25993024 2022-03-15        3787.836                      1
# 449  25993024 2022-03-16        3787.836                      1
# 450  25993024 2022-03-17        3787.836                      1
# 451  25993024 2022-03-18        3787.836                      1
# 452  25993024 2022-03-19        4936.696                      1
# 453  25993024 2022-03-20        5202.696                      2
# 454  25993024 2022-03-21        5202.696                      3
# 455  25993024 2022-03-22        5202.696                      4
# 456  25993024 2022-03-23        4843.496                      1
# 457  25993024 2022-03-24        5095.096                      2
# 458  25993024 2022-03-25        5006.300                      3
# 459  25993024 2022-03-26        5006.300                      4
# 460  25993024 2022-03-27        5006.300                      5
# 461  25993024 2022-03-28        4839.500                      1
# 462  25993024 2022-03-29        4839.500                      1
# 463  25993024 2022-03-30        4839.500                      1
# 464  25993024 2022-03-31        4839.500                      1
# 558  31244414 2022-03-01        2218.312                      1
# 559  31244414 2022-03-02        2218.312                      1
# 560  31244414 2022-03-03        2218.312                      1
# 561  31244414 2022-03-04        2327.396                      1
# 562  31244414 2022-03-05        2327.396                      1
# 563  31244414 2022-03-06        2327.396                      1
# 564  31244414 2022-03-07        2327.396                      1
# 565  31244414 2022-03-08        2327.396                      1
# 566  31244414 2022-03-09        2327.396                      1
# 567  31244414 2022-03-10        2714.132                      1
# 568  31244414 2022-03-11        2714.132                      1
# 569  31244414 2022-03-12        2360.950                      1
# 570  31244414 2022-03-13        2360.950                      1
# 571  31244414 2022-03-14        2362.950                      1
# 572  31244414 2022-03-15        2279.450                      1
# 573  31244414 2022-03-16        2279.450                      1
# 574  31244414 2022-03-17        2678.210                      1
# 575  31244414 2022-03-18        2850.448                      1
# 576  31244414 2022-03-19        2850.448                      1
# 577  31244414 2022-03-20        2850.448                      1
# 578  31244414 2022-03-21        3057.448                      1
# 579  31244414 2022-03-22        3057.448                      1
# 580  31244414 2022-03-23        3057.448                      1
# 581  31244414 2022-03-24        2618.678                      1
# 582  31244414 2022-03-25        2876.078                      1
# 583  31244414 2022-03-26        3297.078                      1
# 584  31244414 2022-03-27        4689.238                      1
# 585  31244414 2022-03-28        4689.238                      1
# 586  31244414 2022-03-29        5231.038                      2
# 587  31244414 2022-03-30        5137.038                      3
# 588  31244414 2022-03-31        4888.178                      1
# 651  35461466 2022-03-01        2415.879                      1
# 652  35461466 2022-03-02        2006.308                      1
# 653  35461466 2022-03-03        2006.308                      1
# 654  35461466 2022-03-04        2006.308                      1
# 655  35461466 2022-03-05        2006.308                      1
# 656  35461466 2022-03-06        2006.308                      1
# 657  35461466 2022-03-07        2006.308                      1
# 658  35461466 2022-03-08        2006.308                      1
# 659  35461466 2022-03-09        2006.308                      1
# 660  35461466 2022-03-10        2006.308                      1
# 661  35461466 2022-03-11        2006.308                      1
# 662  35461466 2022-03-12        2006.308                      1
# 663  35461466 2022-03-13        2006.308                      1
# 664  35461466 2022-03-14        2006.308                      1
# 665  35461466 2022-03-15        2006.308                      1
# 666  35461466 2022-03-16        2006.308                      1
# 667  35461466 2022-03-17        1586.308                      1
# 668  35461466 2022-03-18        1586.308                      1
# 669  35461466 2022-03-19        1586.308                      1
# 670  35461466 2022-03-20        1586.308                      1
# 671  35461466 2022-03-21         746.308                      1
# 672  35461466 2022-03-22         746.308                      1
# 673  35461466 2022-03-23         746.308                      1
# 674  35461466 2022-03-24         746.308                      1
# 675  35461466 2022-03-25         746.308                      1
# 676  35461466 2022-03-26        4360.000                      1
# 677  35461466 2022-03-27        4360.000                      1
# 678  35461466 2022-03-28        4360.000                      1
# 679  35461466 2022-03-29        4360.000                      1
# 680  35461466 2022-03-30        4360.000                      1
# 681  35461466 2022-03-31        5360.000                      2
# 248  36884902 2022-03-01        1389.726                      1
# 249  36884902 2022-03-02        1890.726                      1
# 250  36884902 2022-03-03        1891.726                      1
# 251  36884902 2022-03-04        1893.726                      1
# 252  36884902 2022-03-05        2895.726                      1
# 253  36884902 2022-03-06        3165.706                      1
# 254  36884902 2022-03-07        4167.586                      1
# 255  36884902 2022-03-08        5169.586                      2
# 256  36884902 2022-03-09        5788.088                      3
# 257  36884902 2022-03-10        6163.354                      4
# 258  36884902 2022-03-11        6165.354                      5
# 259  36884902 2022-03-12        6167.354                      6
# 260  36884902 2022-03-13        6169.354                      7
# 261  36884902 2022-03-14        6171.354                      8
# 262  36884902 2022-03-15        6273.354                      9
# 263  36884902 2022-03-16        6275.354                     10
# 264  36884902 2022-03-17        6275.354                     11
# 265  36884902 2022-03-18        6277.354                     12
# 266  36884902 2022-03-19        5824.574                     13
# 267  36884902 2022-03-20        5824.574                     14
# 268  36884902 2022-03-21        5824.574                     15
# 269  36884902 2022-03-22        5675.574                     16
# 270  36884902 2022-03-23        5676.574                     17
# 271  36884902 2022-03-24        5406.628                     18
# 272  36884902 2022-03-25        5408.628                     19
# 273  36884902 2022-03-26        5409.628                     20
# 274  36884902 2022-03-27        5410.628                     21
# 275  36884902 2022-03-28        5411.628                     22
# 276  36884902 2022-03-29        4912.628                      1
# 277  36884902 2022-03-30        4913.628                      1
# 278  36884902 2022-03-31        4914.628                      1
# 93   39314846 2022-03-01        5636.520                      1
# 94   39314846 2022-03-02        5636.520                      2
# 95   39314846 2022-03-03        6910.720                      3
# 96   39314846 2022-03-04        8962.720                      4
# 97   39314846 2022-03-05        9739.960                      5
# 98   39314846 2022-03-06        9421.880                      6
# 99   39314846 2022-03-07        8754.790                      7
# 100  39314846 2022-03-08        8754.790                      8
# 101  39314846 2022-03-09        8754.790                      9
# 102  39314846 2022-03-10        8622.790                     10
# 103  39314846 2022-03-11        8622.790                     11
# 104  39314846 2022-03-12        8622.790                     12
# 105  39314846 2022-03-13        8622.790                     13
# 106  39314846 2022-03-14        8622.790                     14
# 107  39314846 2022-03-15        8622.790                     15
# 108  39314846 2022-03-16        9396.830                     16
# 109  39314846 2022-03-17        9396.830                     17
# 110  39314846 2022-03-18        9594.830                     18
# 111  39314846 2022-03-19        9486.830                     19
# 112  39314846 2022-03-20        7567.690                     20
# 113  39314846 2022-03-21        7567.690                     21
# 114  39314846 2022-03-22        6909.690                     22
# 115  39314846 2022-03-23        7189.690                     23
# 116  39314846 2022-03-24        6854.690                     24
# 117  39314846 2022-03-25        7292.690                     25
# 118  39314846 2022-03-26        7292.690                     26
# 119  39314846 2022-03-27        7292.690                     27
# 120  39314846 2022-03-28        7292.690                     28
# 121  39314846 2022-03-29        8174.830                     29
# 122  39314846 2022-03-30        7872.230                     30
# 123  39314846 2022-03-31        7372.230                     31
# 496  39619396 2022-03-01        2488.327                      1
# 497  39619396 2022-03-02        2488.327                      1
# 498  39619396 2022-03-03        3673.221                      1
# 499  39619396 2022-03-04        3748.839                      1
# 500  39619396 2022-03-05        3748.839                      1
# 501  39619396 2022-03-06        3748.839                      1
# 502  39619396 2022-03-07        3748.839                      1
# 503  39619396 2022-03-08        3965.193                      1
# 504  39619396 2022-03-09        3833.743                      1
# 505  39619396 2022-03-10        3833.743                      1
# 506  39619396 2022-03-11        3413.743                      1
# 507  39619396 2022-03-12        3839.893                      1
# 508  39619396 2022-03-13        3839.893                      1
# 509  39619396 2022-03-14        3839.893                      1
# 510  39619396 2022-03-15        3839.893                      1
# 511  39619396 2022-03-16        3839.893                      1
# 512  39619396 2022-03-17        3771.281                      1
# 513  39619396 2022-03-18        3590.731                      1
# 514  39619396 2022-03-19        3746.941                      1
# 515  39619396 2022-03-20        4035.941                      1
# 516  39619396 2022-03-21        4035.941                      1
# 517  39619396 2022-03-22        5243.823                      2
# 518  39619396 2022-03-23        5711.233                      3
# 519  39619396 2022-03-24        5320.233                      4
# 520  39619396 2022-03-25        5320.233                      5
# 521  39619396 2022-03-26        5320.233                      6
# 522  39619396 2022-03-27        5243.320                      7
# 523  39619396 2022-03-28        5219.686                      8
# 524  39619396 2022-03-29        5219.686                      9
# 525  39619396 2022-03-30        4719.686                      1
# 526  39619396 2022-03-31        4684.856                      1
# 279  43160536 2022-03-01        2202.250                      1
# 280  43160536 2022-03-02        2202.250                      1
# 281  43160536 2022-03-03        2202.250                      1
# 282  43160536 2022-03-04        2202.250                      1
# 283  43160536 2022-03-05        2202.250                      1
# 284  43160536 2022-03-06        2202.250                      1
# 285  43160536 2022-03-07        2202.250                      1
# 286  43160536 2022-03-08        2202.250                      1
# 287  43160536 2022-03-09        2202.250                      1
# 288  43160536 2022-03-10        2202.250                      1
# 289  43160536 2022-03-11        7962.250                      2
# 290  43160536 2022-03-12        8154.250                      3
# 291  43160536 2022-03-13        8154.250                      4
# 292  43160536 2022-03-14        8154.250                      5
# 293  43160536 2022-03-15        8154.250                      6
# 294  43160536 2022-03-16        7854.250                      7
# 295  43160536 2022-03-17        7854.250                      8
# 296  43160536 2022-03-18        7487.250                      9
# 297  43160536 2022-03-19        7487.250                     10
# 298  43160536 2022-03-20        7487.250                     11
# 299  43160536 2022-03-21        7351.250                     12
# 300  43160536 2022-03-22        7351.250                     13
# 301  43160536 2022-03-23        7351.250                     14
# 302  43160536 2022-03-24        7351.250                     15
# 303  43160536 2022-03-25        7351.250                     16
# 304  43160536 2022-03-26        7144.000                     17
# 305  43160536 2022-03-27        7144.000                     18
# 306  43160536 2022-03-28        7144.000                     19
# 307  43160536 2022-03-29        7118.000                     20
# 308  43160536 2022-03-30        7118.000                     21
# 309  43160536 2022-03-31        7118.000                     22
# 372  43933779 2022-03-01        2489.726                      1
# 373  43933779 2022-03-02        2435.726                      1
# 374  43933779 2022-03-03        2653.936                      1
# 375  43933779 2022-03-04        2653.936                      1
# 376  43933779 2022-03-05        2593.637                      1
# 377  43933779 2022-03-06        4593.637                      1
# 378  43933779 2022-03-07        4593.637                      1
# 379  43933779 2022-03-08        4593.637                      1
# 380  43933779 2022-03-09        4593.637                      1
# 381  43933779 2022-03-10        4553.655                      1
# 382  43933779 2022-03-11        4553.655                      1
# 383  43933779 2022-03-12        4553.655                      1
# 384  43933779 2022-03-13        4553.655                      1
# 385  43933779 2022-03-14        4053.655                      1
# 386  43933779 2022-03-15        4703.601                      1
# 387  43933779 2022-03-16        4703.601                      1
# 388  43933779 2022-03-17        4598.201                      1
# 389  43933779 2022-03-18        4598.201                      1
# 390  43933779 2022-03-19        5532.001                      2
# 391  43933779 2022-03-20        5532.001                      3
# 392  43933779 2022-03-21        5532.001                      4
# 393  43933779 2022-03-22        5532.001                      5
# 394  43933779 2022-03-23        5532.001                      6
# 395  43933779 2022-03-24        5484.301                      7
# 396  43933779 2022-03-25        5484.301                      8
# 397  43933779 2022-03-26        5432.601                      9
# 398  43933779 2022-03-27        5378.361                     10
# 399  43933779 2022-03-28        5259.962                     11
# 400  43933779 2022-03-29        4869.409                      1
# 401  43933779 2022-03-30        4869.409                      1
# 402  43933779 2022-03-31        3878.956                      1
# 465  44119627 2022-03-01        1973.297                      1
# 466  44119627 2022-03-02        2031.897                      1
# 467  44119627 2022-03-03        2141.097                      1
# 468  44119627 2022-03-04        2141.097                      1
# 469  44119627 2022-03-05        2141.097                      1
# 470  44119627 2022-03-06        2430.401                      1
# 471  44119627 2022-03-07        2430.401                      1
# 472  44119627 2022-03-08        2430.401                      1
# 473  44119627 2022-03-09        2430.401                      1
# 474  44119627 2022-03-10        2430.401                      1
# 475  44119627 2022-03-11        2712.191                      1
# 476  44119627 2022-03-12        2712.191                      1
# 477  44119627 2022-03-13        3282.791                      1
# 478  44119627 2022-03-14        3394.951                      1
# 479  44119627 2022-03-15        3808.751                      1
# 480  44119627 2022-03-16        3808.751                      1
# 481  44119627 2022-03-17        4163.589                      1
# 482  44119627 2022-03-18        4494.689                      1
# 483  44119627 2022-03-19        4494.689                      1
# 484  44119627 2022-03-20        4494.689                      1
# 485  44119627 2022-03-21        4893.009                      1
# 486  44119627 2022-03-22        5071.807                      2
# 487  44119627 2022-03-23        5012.807                      3
# 488  44119627 2022-03-24        4318.807                      1
# 489  44119627 2022-03-25        4318.807                      1
# 490  44119627 2022-03-26        4184.687                      1
# 491  44119627 2022-03-27        3887.810                      1
# 492  44119627 2022-03-28        3887.810                      1
# 493  44119627 2022-03-29        3627.326                      1
# 494  44119627 2022-03-30        3627.326                      1
# 495  44119627 2022-03-31        3627.326                      1
# 589  44850195 2022-03-01         223.200                      1
# 590  44850195 2022-03-02         223.200                      1
# 591  44850195 2022-03-03         223.200                      1
# 592  44850195 2022-03-04         223.200                      1
# 593  44850195 2022-03-05         223.200                      1
# 594  44850195 2022-03-06         223.200                      1
# 595  44850195 2022-03-07         223.200                      1
# 596  44850195 2022-03-08         223.200                      1
# 597  44850195 2022-03-09         223.200                      1
# 598  44850195 2022-03-10         223.200                      1
# 599  44850195 2022-03-11         223.200                      1
# 600  44850195 2022-03-12         223.200                      1
# 601  44850195 2022-03-13         223.200                      1
# 602  44850195 2022-03-14         223.200                      1
# 603  44850195 2022-03-15         223.200                      1
# 604  44850195 2022-03-16         144.000                      1
# 605  44850195 2022-03-17         144.000                      1
# 606  44850195 2022-03-18         144.000                      1
# 607  44850195 2022-03-19         144.000                      1
# 608  44850195 2022-03-20         144.000                      1
# 609  44850195 2022-03-21         144.000                      1
# 610  44850195 2022-03-22         352.660                      1
# 611  44850195 2022-03-23        1766.340                      1
# 612  44850195 2022-03-24        2523.940                      1
# 613  44850195 2022-03-25        2726.020                      1
# 614  44850195 2022-03-26        3091.512                      1
# 615  44850195 2022-03-27        4992.702                      1
# 616  44850195 2022-03-28        4992.702                      1
# 617  44850195 2022-03-29        5102.102                      2
# 618  44850195 2022-03-30        5420.102                      3
# 619  44850195 2022-03-31        5721.902                      4
# 186  44901759 2022-03-01        4784.000                      1
# 187  44901759 2022-03-02        4784.000                      1
# 188  44901759 2022-03-03        4784.000                      1
# 189  44901759 2022-03-04        4784.000                      1
# 190  44901759 2022-03-05        4784.000                      1
# 191  44901759 2022-03-06        4784.000                      1
# 192  44901759 2022-03-07        6764.000                      2
# 193  44901759 2022-03-08        6764.000                      3
# 194  44901759 2022-03-09        6764.000                      4
# 195  44901759 2022-03-10        6764.000                      5
# 196  44901759 2022-03-11        6764.000                      6
# 197  44901759 2022-03-12        6764.000                      7
# 198  44901759 2022-03-13        6764.000                      8
# 199  44901759 2022-03-14        6764.000                      9
# 200  44901759 2022-03-15        2764.000                      1
# 201  44901759 2022-03-16        1980.000                      1
# 202  44901759 2022-03-17        1980.000                      1
# 203  44901759 2022-03-18        1980.000                      1
# 204  44901759 2022-03-19        1980.000                      1
# 205  44901759 2022-03-20        1980.000                      1
# 206  44901759 2022-03-21        1980.000                      1
# 207  44901759 2022-03-22        1980.000                      1
# 208  44901759 2022-03-23        1980.000                      1
# 209  44901759 2022-03-24        1980.000                      1
# 210  44901759 2022-03-25        1980.000                      1
# 211  44901759 2022-03-26        1980.000                      1
# 212  44901759 2022-03-27        1980.000                      1
# 213  44901759 2022-03-28        1980.000                      1
# 214  44901759 2022-03-29        1980.000                      1
# 215  44901759 2022-03-30        1980.000                      1
# 216  44901759 2022-03-31        1980.000                      1
# 341  45426067 2022-03-01        1135.780                      1
# 342  45426067 2022-03-02        1135.780                      1
# 343  45426067 2022-03-03        1135.780                      1
# 344  45426067 2022-03-04        1460.140                      1
# 345  45426067 2022-03-05        1953.940                      1
# 346  45426067 2022-03-06        1953.940                      1
# 347  45426067 2022-03-07        2051.940                      1
# 348  45426067 2022-03-08        1990.140                      1
# 349  45426067 2022-03-09        1990.140                      1
# 350  45426067 2022-03-10        2431.540                      1
# 351  45426067 2022-03-11        2431.540                      1
# 352  45426067 2022-03-12        2431.540                      1
# 353  45426067 2022-03-13        2431.540                      1
# 354  45426067 2022-03-14        2431.540                      1
# 355  45426067 2022-03-15        3025.700                      1
# 356  45426067 2022-03-16        3025.700                      1
# 357  45426067 2022-03-17        4214.120                      1
# 358  45426067 2022-03-18        5176.120                      2
# 359  45426067 2022-03-19        5476.920                      3
# 360  45426067 2022-03-20        5476.920                      4
# 361  45426067 2022-03-21        5637.586                      5
# 362  45426067 2022-03-22        5637.586                      6
# 363  45426067 2022-03-23        5491.186                      7
# 364  45426067 2022-03-24        5491.186                      8
# 365  45426067 2022-03-25        5319.586                      9
# 366  45426067 2022-03-26        5944.786                     10
# 367  45426067 2022-03-27        5893.766                     11
# 368  45426067 2022-03-28        5893.766                     12
# 369  45426067 2022-03-29        5484.766                     13
# 370  45426067 2022-03-30        5484.766                     14
# 371  45426067 2022-03-31        5484.766                     15
# 62   47662326 2022-03-01       23585.726                      1
# 63   47662326 2022-03-02       24085.726                      2
# 64   47662326 2022-03-03       26185.904                      3
# 65   47662326 2022-03-04       26185.904                      4
# 66   47662326 2022-03-05       26685.904                      5
# 67   47662326 2022-03-06       27688.384                      6
# 68   47662326 2022-03-07       29468.484                      7
# 69   47662326 2022-03-08       29468.484                      8
# 70   47662326 2022-03-09       30981.414                      9
# 71   47662326 2022-03-10       30981.414                     10
# 72   47662326 2022-03-11       33246.214                     11
# 73   47662326 2022-03-12       33649.814                     12
# 74   47662326 2022-03-13       35850.214                     13
# 75   47662326 2022-03-14       36850.214                     14
# 76   47662326 2022-03-15       41043.574                     15
# 77   47662326 2022-03-16       42071.094                     16
# 78   47662326 2022-03-17       42468.694                     17
# 79   47662326 2022-03-18       41468.694                     18
# 80   47662326 2022-03-19       39491.494                     19
# 81   47662326 2022-03-20       38156.294                     20
# 82   47662326 2022-03-21       37675.494                     21
# 83   47662326 2022-03-22       38646.114                     22
# 84   47662326 2022-03-23       38407.714                     23
# 85   47662326 2022-03-24       40407.714                     24
# 86   47662326 2022-03-25       39168.514                     25
# 87   47662326 2022-03-26       37790.434                     26
# 88   47662326 2022-03-27       39083.834                     27
# 89   47662326 2022-03-28       39332.357                     28
# 90   47662326 2022-03-29       40622.634                     29
# 91   47662326 2022-03-30       39447.164                     30
# 92   47662326 2022-03-31       40114.898                     31
# 310  49689927 2022-03-01        2050.000                      1
# 311  49689927 2022-03-02        2050.000                      1
# 312  49689927 2022-03-03        2350.000                      1
# 313  49689927 2022-03-04        2350.000                      1
# 314  49689927 2022-03-05        2350.000                      1
# 315  49689927 2022-03-06        2250.000                      1
# 316  49689927 2022-03-07        2350.000                      1
# 317  49689927 2022-03-08        1300.000                      1
# 318  49689927 2022-03-09        2400.000                      1
# 319  49689927 2022-03-10        2600.000                      1
# 320  49689927 2022-03-11        2800.000                      1
# 321  49689927 2022-03-12        3000.000                      1
# 322  49689927 2022-03-13        3250.000                      1
# 323  49689927 2022-03-14        3450.000                      1
# 324  49689927 2022-03-15        3800.000                      1
# 325  49689927 2022-03-16        3750.000                      1
# 326  49689927 2022-03-17        5050.000                      2
# 327  49689927 2022-03-18        5250.000                      3
# 328  49689927 2022-03-19        5700.000                      4
# 329  49689927 2022-03-20        5900.000                      5
# 330  49689927 2022-03-21        6100.000                      6
# 331  49689927 2022-03-22        6400.000                      7
# 332  49689927 2022-03-23        6400.000                      8
# 333  49689927 2022-03-24        6700.000                      9
# 334  49689927 2022-03-25        6700.000                     10
# 335  49689927 2022-03-26        6850.000                     11
# 336  49689927 2022-03-27        7350.000                     12
# 337  49689927 2022-03-28        7350.000                     13
# 338  49689927 2022-03-29        8600.000                     14
# 339  49689927 2022-03-30        8700.000                     15
# 340  49689927 2022-03-31        9100.000                     16
# 217  50185392 2022-03-01        3836.037                      1
# 218  50185392 2022-03-02        3630.037                      1
# 219  50185392 2022-03-03        3630.037                      1
# 220  50185392 2022-03-04        3630.037                      1
# 221  50185392 2022-03-05        3630.037                      1
# 222  50185392 2022-03-06        4130.037                      1
# 223  50185392 2022-03-07        5130.037                      2
# 224  50185392 2022-03-08        5630.037                      3
# 225  50185392 2022-03-09        5218.037                      4
# 226  50185392 2022-03-10        5088.037                      5
# 227  50185392 2022-03-11        6848.037                      6
# 228  50185392 2022-03-12       16877.037                      7
# 229  50185392 2022-03-13       16877.037                      8
# 230  50185392 2022-03-14       16877.037                      9
# 231  50185392 2022-03-15       24903.537                     10
# 232  50185392 2022-03-16       24903.537                     11
# 233  50185392 2022-03-17       24903.537                     12
# 234  50185392 2022-03-18       24903.537                     13
# 235  50185392 2022-03-19       25703.537                     14
# 236  50185392 2022-03-20       25812.373                     15
# 237  50185392 2022-03-21       25812.373                     16
# 238  50185392 2022-03-22       25206.373                     17
# 239  50185392 2022-03-23       25206.373                     18
# 240  50185392 2022-03-24       25091.500                     19
# 241  50185392 2022-03-25       25091.500                     20
# 242  50185392 2022-03-26       25091.500                     21
# 243  50185392 2022-03-27       25091.500                     22
# 244  50185392 2022-03-28       25591.500                     23
# 245  50185392 2022-03-29       26091.500                     24
# 246  50185392 2022-03-30       26091.500                     25
# 247  50185392 2022-03-31       25985.500                     26
# 155  51432947 2022-03-01        3112.469                      1
# 156  51432947 2022-03-02        3462.269                      1
# 157  51432947 2022-03-03        4148.269                      1
# 158  51432947 2022-03-04        5148.269                      2
# 159  51432947 2022-03-05        6785.389                      3
# 160  51432947 2022-03-06        7785.389                      4
# 161  51432947 2022-03-07        8785.389                      5
# 162  51432947 2022-03-08        9088.189                      6
# 163  51432947 2022-03-09        9088.189                      7
# 164  51432947 2022-03-10        9088.189                      8
# 165  51432947 2022-03-11       10072.935                      9
# 166  51432947 2022-03-12       10072.935                     10
# 167  51432947 2022-03-13       10072.935                     11
# 168  51432947 2022-03-14       10072.935                     12
# 169  51432947 2022-03-15        9816.170                     13
# 170  51432947 2022-03-16       10530.840                     14
# 171  51432947 2022-03-17       12109.880                     15
# 172  51432947 2022-03-18       12964.960                     16
# 173  51432947 2022-03-19       13964.960                     17
# 174  51432947 2022-03-20       13964.960                     18
# 175  51432947 2022-03-21       14612.525                     19
# 176  51432947 2022-03-22       14612.525                     20
# 177  51432947 2022-03-23       15621.845                     21
# 178  51432947 2022-03-24       15662.433                     22
# 179  51432947 2022-03-25       15474.786                     23
# 180  51432947 2022-03-26       15877.666                     24
# 181  51432947 2022-03-27       16702.614                     25
# 182  51432947 2022-03-28       16702.614                     26
# 183  51432947 2022-03-29       16926.914                     27
# 184  51432947 2022-03-30       16926.914                     28
# 185  51432947 2022-03-31       16106.314                     29
# 620  54788782 2022-03-01        1350.000                      1
# 621  54788782 2022-03-02        1050.000                      1
# 622  54788782 2022-03-03        1200.000                      1
# 623  54788782 2022-03-04        1050.000                      1
# 624  54788782 2022-03-05        1050.000                      1
# 625  54788782 2022-03-06        1500.000                      1
# 626  54788782 2022-03-07        1650.000                      1
# 627  54788782 2022-03-08        1650.000                      1
# 628  54788782 2022-03-09        1650.000                      1
# 629  54788782 2022-03-10        1650.000                      1
# 630  54788782 2022-03-11        1500.000                      1
# 631  54788782 2022-03-12        1500.000                      1
# 632  54788782 2022-03-13        1650.000                      1
# 633  54788782 2022-03-14        1650.000                      1
# 634  54788782 2022-03-15        2050.000                      1
# 635  54788782 2022-03-16        2050.000                      1
# 636  54788782 2022-03-17        2200.000                      1
# 637  54788782 2022-03-18        2200.000                      1
# 638  54788782 2022-03-19        2350.000                      1
# 639  54788782 2022-03-20        2500.000                      1
# 640  54788782 2022-03-21        2500.000                      1
# 641  54788782 2022-03-22        2650.000                      1
# 642  54788782 2022-03-23        2800.000                      1
# 643  54788782 2022-03-24        2800.000                      1
# 644  54788782 2022-03-25        2800.000                      1
# 645  54788782 2022-03-26        2800.000                      1
# 646  54788782 2022-03-27        2800.000                      1
# 647  54788782 2022-03-28        3250.000                      1
# 648  54788782 2022-03-29        3250.000                      1
# 649  54788782 2022-03-30        5350.000                      2
# 650  54788782 2022-03-31        5350.000                      3
# 403  54960619 2022-03-01           0.000                      1
# 404  54960619 2022-03-02           0.000                      1
# 405  54960619 2022-03-03           0.000                      1
# 406  54960619 2022-03-04           0.000                      1
# 407  54960619 2022-03-05           0.000                      1
# 408  54960619 2022-03-06           0.000                      1
# 409  54960619 2022-03-07           0.000                      1
# 410  54960619 2022-03-08           0.000                      1
# 411  54960619 2022-03-09           0.000                      1
# 412  54960619 2022-03-10           0.000                      1
# 413  54960619 2022-03-11           0.000                      1
# 414  54960619 2022-03-12           0.000                      1
# 415  54960619 2022-03-13           0.000                      1
# 416  54960619 2022-03-14           0.000                      1
# 417  54960619 2022-03-15           0.000                      1
# 418  54960619 2022-03-16           0.000                      1
# 419  54960619 2022-03-17           0.000                      1
# 420  54960619 2022-03-18           0.000                      1
# 421  54960619 2022-03-19           0.000                      1
# 422  54960619 2022-03-20       22000.000                      2
# 423  54960619 2022-03-21       22000.000                      3
# 424  54960619 2022-03-22       22000.000                      4
# 425  54960619 2022-03-23       22000.000                      5
# 426  54960619 2022-03-24       22000.000                      6
# 427  54960619 2022-03-25       22000.000                      7
# 428  54960619 2022-03-26       22000.000                      8
# 429  54960619 2022-03-27       22000.000                      9
# 430  54960619 2022-03-28       24000.000                     10
# 431  54960619 2022-03-29       42640.000                     11
# 432  54960619 2022-03-30       42640.000                     12
# 433  54960619 2022-03-31       42640.000                     13
# 124  55200938 2022-03-01        7206.154                      1
# 125  55200938 2022-03-02        6604.154                      2
# 126  55200938 2022-03-03        6538.154                      3
# 127  55200938 2022-03-04        6411.715                      4
# 128  55200938 2022-03-05        5732.946                      5
# 129  55200938 2022-03-06        6830.946                      6
# 130  55200938 2022-03-07        6941.946                      7
# 131  55200938 2022-03-08        7789.846                      8
# 132  55200938 2022-03-09        7789.846                      9
# 133  55200938 2022-03-10        7695.846                     10
# 134  55200938 2022-03-11        8056.486                     11
# 135  55200938 2022-03-12        8056.486                     12
# 136  55200938 2022-03-13        8065.286                     13
# 137  55200938 2022-03-14        7927.286                     14
# 138  55200938 2022-03-15        7862.806                     15
# 139  55200938 2022-03-16        7807.306                     16
# 140  55200938 2022-03-17        7604.306                     17
# 141  55200938 2022-03-18        7550.066                     18
# 142  55200938 2022-03-19        7438.666                     19
# 143  55200938 2022-03-20        6172.966                     20
# 144  55200938 2022-03-21        5427.666                     21
# 145  55200938 2022-03-22        5002.126                     22
# 146  55200938 2022-03-23        5002.126                     23
# 147  55200938 2022-03-24        5409.806                     24
# 148  55200938 2022-03-25        5409.806                     25
# 149  55200938 2022-03-26        5675.966                     26
# 150  55200938 2022-03-27        5896.642                     27
# 151  55200938 2022-03-28        6519.442                     28
# 152  55200938 2022-03-29        6843.182                     29
# 153  55200938 2022-03-30        7031.182                     30
# 154  55200938 2022-03-31        7536.602                     31
# 527  55443594 2022-03-01        1196.602                      1
# 528  55443594 2022-03-02        2196.602                      1
# 529  55443594 2022-03-03        2196.602                      1
# 530  55443594 2022-03-04        2196.602                      1
# 531  55443594 2022-03-05        2196.602                      1
# 532  55443594 2022-03-06        2196.602                      1
# 533  55443594 2022-03-07        3196.602                      1
# 534  55443594 2022-03-08        3196.602                      1
# 535  55443594 2022-03-09        3807.802                      1
# 536  55443594 2022-03-10        3807.802                      1
# 537  55443594 2022-03-11        3807.802                      1
# 538  55443594 2022-03-12        4271.482                      1
# 539  55443594 2022-03-13        4271.482                      1
# 540  55443594 2022-03-14        4318.282                      1
# 541  55443594 2022-03-15        4114.282                      1
# 542  55443594 2022-03-16        3999.282                      1
# 543  55443594 2022-03-17        3868.282                      1
# 544  55443594 2022-03-18        3604.282                      1
# 545  55443594 2022-03-19        3604.282                      1
# 546  55443594 2022-03-20        3238.280                      1
# 547  55443594 2022-03-21        3238.280                      1
# 548  55443594 2022-03-22        3489.480                      1
# 549  55443594 2022-03-23        3489.480                      1
# 550  55443594 2022-03-24        5489.480                      2
# 551  55443594 2022-03-25        7489.480                      3
# 552  55443594 2022-03-26        7489.480                      4
# 553  55443594 2022-03-27        8197.300                      5
# 554  55443594 2022-03-28        8397.300                      6
# 555  55443594 2022-03-29        8726.500                      7
# 556  55443594 2022-03-30        9726.500                      8
# 557  55443594 2022-03-31        9726.500                      9
# 0    57207697 2022-03-01        5875.400                      1
# 1    57207697 2022-03-02        5875.400                      2
# 2    57207697 2022-03-03        7835.400                      3
# 3    57207697 2022-03-04        9735.400                      4
# 4    57207697 2022-03-05       11635.400                      5
# 5    57207697 2022-03-06       11635.400                      6
# 6    57207697 2022-03-07       11635.400                      7
# 7    57207697 2022-03-08       11635.400                      8
# 8    57207697 2022-03-09       11635.400                      9
# 9    57207697 2022-03-10       11635.400                     10
# 10   57207697 2022-03-11       10940.000                     11
# 11   57207697 2022-03-12       10940.000                     12
# 12   57207697 2022-03-13       10940.000                     13
# 13   57207697 2022-03-14       10940.000                     14
# 14   57207697 2022-03-15       10940.000                     15
# 15   57207697 2022-03-16       10940.000                     16
# 16   57207697 2022-03-17       10940.000                     17
# 17   57207697 2022-03-18       10940.000                     18
# 18   57207697 2022-03-19       10540.000                     19
# 19   57207697 2022-03-20       10540.000                     20
# 20   57207697 2022-03-21       10540.000                     21
# 21   57207697 2022-03-22       12535.000                     22
# 22   57207697 2022-03-23       13535.000                     23
# 23   57207697 2022-03-24       13915.000                     24
# 24   57207697 2022-03-25       13915.000                     25
# 25   57207697 2022-03-26       13915.000                     26
# 26   57207697 2022-03-27       13915.000                     27
# 27   57207697 2022-03-28       13915.000                     28
# 28   57207697 2022-03-29       13915.000                     29
# 29   57207697 2022-03-30       17733.000                     30
# 30   57207697 2022-03-31       16753.000                     31

# %%
result = march_users.groupby('User_id')['Consecutive day count'].max().reset_index()
result[result['Consecutive day count'] >= 20].sort_values(by = 'Consecutive day count' ,ascending = False)
# Out:
#      User_id  Consecutive day count
# 5   39314846                     31
# 13  47662326                     31
# 19  55200938                     31
# 21  57207697                     31
# 16  51432947                     29
# 15  50185392                     26
# 4   36884902                     22
# 7   43160536                     22

# %% [markdown]
# Check the result

# %%
march_users[march_users['User_id'] == 39314846]
# Out:
# Empty DataFrame
# Columns: [User_id, DATE, Loyalty Points, Consecutive day count]
# Index: []
